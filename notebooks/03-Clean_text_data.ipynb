# %%
# !cat "s02_Split_dataset.py"
# Out:
# from Imports import *
# from s01_Load_dataset import data
#
#
# # Choose a random_state seed
# random_seed = 42
#
# # 1. First split: train (90 %) / temp (10 %)
# ds_train_temp = data['train'].train_test_split(train_size=0.90, seed=random_seed)
#
# # 2. Second split on temp: validation (75 %) / test (25 %)
# ds_temp = ds_train_temp['test'].train_test_split(train_size=0.75, seed=random_seed)
#
# # Put those splits inside a DatasetDict
# ds = DatasetDict({
#     'train': ds_train_temp['train'],  # 90 %  of the whole dataset
#     'valid': ds_temp['train'],        # 7.5 % of the whole dataset
#     'test': ds_temp['test']           # 2.5 % of the whole dataset
# })
#
# del ds_train_temp
# del ds_temp
# del data

# %%
from s02_Split_dataset import ds

# %%
from s03_Clean_text_data import (
    TextCleaner,
    clean_dataset,
    verify_cleaning,
)

# %%
cleaner = TextCleaner()

# %%
print("Cleaning datasets in progress…")
ds_train = clean_dataset(ds['train'], cleaner)
# Out:
# Cleaning datasets in progress…
# Map:   0%|          | 0/189155 [00:00<?, ? examples/s]

# %%
ds_val = clean_dataset(ds['valid'], cleaner)
# Out:
# Map:   0%|          | 0/15763 [00:00<?, ? examples/s]

# %%
ds_test = clean_dataset(ds['test'], cleaner)
# Out:
# Map:   0%|          | 0/5255 [00:00<?, ? examples/s]

# %%
print("\nVerifying the training set:")
verify_cleaning(ds_train)
# Out:
# Verifying the training set:
# Cleaning Verification
# Example 1 is clean:
# EN: Show Pathfinder Lander Image
# FR: Afficher l'image de Pathfinder LanderImage/ info menu item (should be translated)
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 2 is clean:
# EN: Publisher
# FR: Éditeur
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 3 is clean:
# EN: Remove entry
# FR: Supprimer l' entrée
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 4 is clean:
# EN: Application Preference Order determines which applications will be associated with the specified & MIME; type.
# FR: Applications par ordre de préférence : détermine les associations qui sont associées à ce type & MIME;.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 5 is clean:
# EN: CSS Validator
# FR: Validateur CSS
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯

# %%
print("\nVerifying the validation set:")
verify_cleaning(ds_val)
# Out:
# Verifying the validation set:
# Cleaning Verification
# Example 1 is clean:
# EN: Mobile Number
# FR: Numéro de mobile
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 2 is clean:
# EN: Set the selected profile as the default for new terminal sessions
# FR: Sélectionner le profil par défaut des nouvelles sessions de terminal
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 3 is clean:
# EN: John Tapsell
# FR: John Tapsell
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 4 is clean:
# EN: Tel Aviv
# FR: Tel AvivCity in Italy
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 5 is clean:
# EN: The reporting assistant is disabled because the crash handler dialog was started in safe mode. You can manually
# report this bug to %1 (including the backtrace from the Developer Information tab.)
# FR: L'assistant de rapport de bogue est désactivé car le gestionnaire de plantage a été démarré en mode sécurisé.
# ...

# %%
print("\nVerifying the test set:")
verify_cleaning(ds_test)
# Out:
# Verifying the test set:
# Cleaning Verification
# Example 1 is clean:
# EN: :
# FR: :
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 2 is clean:
# EN: Depending on the size of the game board and the difficulty level chosen each individual & kappname; puzzle may
# take up to a few hours to solve.
# FR: Chaque & kappname; peut prendre quelques heures pour être résolu, cela dépend de la taille du plateau de jeu et
# du niveau de difficulté.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 3 is clean:
# EN: ATMOSphere Control Center Module
# FR: Module de configuration ATMOSphereKeywords
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 4 is clean:
# EN: http: / /localhost:631/ documentation. html
# FR: http: / /localhost:631/ documentation. html
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Example 5 is clean:
# EN: Description
# FR: Arnold Kraschinski
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯

# %%
print("\nCleaning completed! The datasets have been updated directly.")
# Out:
# Cleaning completed! The datasets have been updated directly.
