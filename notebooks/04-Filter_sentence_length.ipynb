# %%
from Imports import *

# %%
# Definitions

# %%
from s04_Filter_sentence_length import (
    FilterLength,
    display_random_samples,
)

# %%
# Runs

# %%
from s03_Clean_text_data import (
    ds_train,
    ds_val,
    ds_test,
)
# Out:
# ...
# Map:   0%|          | 0/5255 [00:00<?, ? examples/s]

# %%
# Apply that filter
flength = FilterLength()

# %%
ds_train = ds_train.filter(flength.filter_length)
# Out:
# Filter:   0%|          | 0/189155 [00:00<?, ? examples/s]

# %%
ds_val = ds_val.filter(flength.filter_length)
# Out:
# Filter:   0%|          | 0/15763 [00:00<?, ? examples/s]

# %% [raw]
# # Not applied on ds_test to avoid biasing the evaluation

# %%
# Check

# %%
flength.check_length_distribution(ds_train, "Train dataset")
# Out:
#  Train dataset − Length Check
# Total number of sentences: 82223
# Min length (EN): 3, Max length (EN): 27
# Min length (FR): 3, Max length (FR): 28
# All sentences comply with the 3 to 128 token limit.

# %%
flength.check_length_distribution(ds_val, "Validation dataset")
# Out:
#  Validation dataset − Length Check
# Total number of sentences: 6938
# Min length (EN): 3, Max length (EN): 25
# Min length (FR): 3, Max length (FR): 31
# All sentences comply with the 3 to 128 token limit.

# %%
flength.check_length_distribution(ds_test, "Test dataset")
# Out:
#  Test dataset − Length Check
# Total number of sentences: 5255
# Min length (EN): 1, Max length (EN): 193
# Min length (FR): 1, Max length (FR): 274
# 2492 sentences do NOT meet the token limits!
#  Examples
# EN: :
# FR: :
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Description
# FR: Arnold Kraschinski
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Folders
# FR: Dossiers
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Very good
# FR: Vraiment bonThe quality of music
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Untitled%1
# FR: sans-titre%1
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯

# %%
display_random_samples(ds_train, "Train dataset")
# Out:
# Train dataset: 10 random samples
# EN: Tools Filled Circle
# FR: Outils Cercle plein
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Americanized tiles inspired by Japanese Mahjongg tiles
# FR: Tuiles américanisées inspirées par les tuiles du Mahjongg japonaisName
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Nothing to clean for %1
# FR: Rien à nettoyer pour %1
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: One or more BCD fields out of range for %1
# FR: Au moins un des champs BCD est en dehors de la plage autorisée pour %1.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Remove this price item from the file
# FR: Supprimer ce cours du fichier
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Could not extract first message id from server response: %1
# FR: Impossible de réceptionner l'identifiant du premier message dans la réponse du serveur : %1
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Open in Dolphin
# FR: Ouvrir dans Dolphin
# ...

# %%
display_random_samples(ds_val, "Validation dataset")
# Out:
# Validation dataset: 10 random samples
# EN: The %1-axis is unsupported in XQuery
# FR: L'axe %1 n'est pas pris en charge dans XQuery
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: & Bernd. Johannes. Wuebben;
# FR: & Bernd. Johannes. Wuebben;
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Use gestures for activating sticky keys and slow keys
# FR: Utilisez les gestes pour activer l'automaintien et les touches lentes
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: Ancient Egyptians Dark
# FR: Égypte ancienne et sombreComment
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: This drop down selection box can be used to select alternative dictionaries.
# FR: Cette boîte à sélection déroulante peut être utilisée pour sélectionner des dictionnaires alternatifs.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: No project specified.
# FR: Aucun projet n'est spécifié.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# ...
