# %%
from Imports import *

# %%
from s06_Smart_lowercase_conversion import (
    ds_train, ds_val, ds_test,
    display_random_samples
)
# Out:
# Map:   0%|          | 0/189155 [00:00<?, ? examples/s]
# Map:   0%|          | 0/15763 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5255 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/189155 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/15763 [00:00<?, ? examples/s]
# Number of examples after strict removal of all repeated sentences in train dataset: 75089
# Number of examples after strict removal of all repeated sentences in validation dataset: 6731
# Map:   0%|          | 0/75089 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6731 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5255 [00:00<?, ? examples/s]

# %%
display_random_samples(ds_train, "Train dataset")
# Out:
# Train dataset: 10 random samples
# EN: error creating contact
# FR: erreur lors de la création du contact
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: choose sky culture.
# FR: choisissez une culture céleste.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: & kappname;, a breakout-like game.
# FR: & kappname;, un jeu de type breakout
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: double-clicking on a channel in the sidebar opens the url of the channel.
# FR: double-cliquer sur une chaîne dans le panneau latéral ouvre la page internet de la chaîne.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: disabled color effect amount
# FR: quantité d'effet de couleur pour un élément désactivé
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: modify the selected task or variable.
# FR: modifie la tâche ou la variable sélectionnée.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: trust certifications made by this certificate...
# FR: accorder la confiance aux certifications effectuées par ce certificat....
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: & fit to page
# FR: ajuster à la &page
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: an image viewer
# FR: une visionneuse d' images
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: name of focused object
# FR: nom de l'objet portant le focus
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯

# %%
display_random_samples(ds_val, "Validation dataset")
# Out:
# Validation dataset: 10 random samples
# EN: & carsten. pfeiffer; & carsten. pfeiffer. mail;
# FR: & carsten. pfeiffer; & carsten. pfeiffer. mail;
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: contact email-1 address type
# FR: type de l'adresse électronique n°1 du contact
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: or other strange things you notice before or after the crash.
# FR: ou toutes les choses étranges que vous avez remarqué avant ou après le plantage. @info/ rich
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: go to last row
# FR: aller à la dernière ligne
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: one of the contacts (%1) that you have selected is not associated with an address book entry.
# FR: un des contacts sélectionnés (%1) n'est pas associé avec un contact de votre carnet d'adresses.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: could not create temporary file for output "%1"
# FR: impossible de créer un fichier temporaire pour la sortie de « %1 »
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: cannot save settings to the photograph tone mapping text file.
# FR: impossible de charger les paramètres du fichier de configuration de redimensionnement.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: then click finish to close & kapptemplate;.
# FR: cliquez ensuite sur terminer pour fermer & kapptemplate;.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: first select either HTTP; or SMTP (email) to determine which protocol to use.
# FR: choisissez d'abord soit HTTP; ou SMTP (courrier électronique) pour déterminer quel protocole utiliser.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: list color for missing conversion rate
# FR: liste des couleurs pour le taux de conversion manquant
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯

# %%
display_random_samples(ds_test, "Test dataset")
# Out:
# Test dataset: 10 random samples
# EN: minimize
# FR: minimisernote this is a krunner keyword
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: & kteatime; copyright & copy; 1998-1999 by & matthias. hoelzer-kluepfel; & matthias. hoelzer-kluepfel. mail;
# FR: & kteatime; copyright & copy; 1998-1999 par & matthias. hoelzer-kluepfel; & matthias. hoelzer-kluepfel. mail;
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: finnish for kids
# FR: finlandais pour enfantslesson name
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: parse error: expected command, got something else
# FR: erreur d'analyse : commande attendue.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: taglib & ktrm code
# FR: code de taglib & ktrm
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: for email alarms:
# FR: pour les alarmes par courrier électronique :
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: dave corrie
# FR: dave corrie
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: the lower list, labeled menu, shows the appearance of the view filter menu, which you can reach from the menu
# bar; the order of the filters in the this menu can be configured in this list.
# FR: la liste inférieure, nommée menu, montre l'apparence du menu affichage filtre, auquel vous pouvez accéder par
# la barre de menus. l'ordre des filtres dans ce menu peut être configuré dans cette liste.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: for example, if cell a1 has been given the name fred then you can enter a formula such as ='fred '+ 2 into
# another cell which would always give the result of adding 2 to the value in a1 no matter where the formula cell was
# copied to.
# FR: par exemple, si la cellule a1 a pour nom fred, vous pouvez saisir une formule comme ='fred '+ 2 dans une autre
# cellule qui doit toujours additionner la valeur de a1 sans se soucier d'où la formule a été copiée.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# EN: prevent empty clipboard
# FR: empêcher le presse-papiers d'être vidé
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
