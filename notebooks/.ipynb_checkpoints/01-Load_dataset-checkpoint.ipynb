# %%
# !cat "s01_Load_dataset.py"
# Out:
# from Imports import *
# data = load_dataset('kde4', lang1='en', lang2='fr')

# %%
# %run "s01_Load_dataset.py"
# Out:
# Using the latest cached version of the module from /home/ludo/.cache/huggingface/modules/datasets_modules/datasets/kde4/243129fb2398d5b0b4f7f6831ab27ad84774b7ce374cf10f60f6e1ff331648ac (last modified on Tue Nov  4 16:08:06 2025) since it couldn't be found locally at kde4, or remotely on the Hugging Face Hub.

# %%
print(data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 210173
#     })
# })

# %%
# Exemple
print(data['train'][0])
# Out:
# {'id': '0', 'translation': {'en': 'Lauri Watts', 'fr': 'Lauri Watts'}}

# %%
nb_examples = 20
ds_train = data['train']

for i in range(nb_examples):
    row = ds_train[i]
    printmd(f"**ID:** {row['id']}")
    printmd(f"**EN:** {row['translation']['en']}")
    printmd(f"**FR:** {row['translation']['fr']}")
    print("⎯" * 40)
# Out:
# **ID:** 0
# **EN:** Lauri Watts
# **FR:** Lauri Watts
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 1
# **EN:** & Lauri. Watts. mail;
# **FR:** & Lauri. Watts. mail;
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 2
# **EN:** ROLES_OF_TRANSLATORS
# **FR:** & traducteurJeromeBlanc;
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 3
# **EN:** 2006-02-26 3.5.1
# **FR:** 2006-02-26 3.5.1
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 4
# **EN:** The Babel & konqueror; plugin gives you quick access to the Babelfish translation service.
# **FR:** Le module externe Babel pour & konqueror; vous donne un accès rapide au service de traduction Babelfish.
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 5
# **EN:** KDE
# **FR:** KDE
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 6
# **EN:** kdeaddons
# **FR:** kdeaddons
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 7
# **EN:** konqueror
# **FR:** konqueror
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 8
# **EN:** plugins
# **FR:** Modules externes
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 9
# **EN:** babelfish
# **FR:** babelfish
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# **ID:** 10
# ...
