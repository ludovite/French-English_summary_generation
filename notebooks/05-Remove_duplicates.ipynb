# %%
from Imports import *
from s05_Remove_duplicates import (
    ds_test, ds_val, ds_train,
    check_duplicates,
)
# Out:
# ...
# Filter:   0%|          | 0/15763 [00:00<?, ? examples/s]
# Number of examples after strict removal of all repeated sentences in train dataset: 75089
# Number of examples after strict removal of all repeated sentences in validation dataset: 6731

# %%
# Post-verification after cleaning

# %%
check_duplicates(ds_train, "Train dataset (final)")
check_duplicates(ds_val, "Validation dataset (final)")
# Out:
# Train dataset (final) − Duplicate Check
# Total number of examples: 75089
# Number of unique examples: 71213
# 1795 sentence pairs are duplicated!
# Examples of the most frequent duplicates:
# (25x) EN: Ctrl; C Edit Copy
# (25x) FR: Ctrl; C Édition Copier
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# (2x) EN: Tunnel interface IP address: %1
# (2x) FR: Adresse IP de l'interface tunnel : %1
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# (2x) EN: Mutt dotlock privileged
# (2x) FR: Mutt dotlock privilégié
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# (3x) EN: file to open
# (3x) FR: fichier à ouvrir
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# (11x) EN: & Pamela. Roberts;
# (11x) FR: & Pamela. Roberts;
# ⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
# Validation dataset (final) − Duplicate Check
# Total number of examples: 6731
# Number of unique examples: 6616
# 59 sentence pairs are duplicated!
# Examples of the most frequent duplicates:
# (2x) EN: Ctrl; X Edit Cut
# ...
